# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import netCDF4 as ncf

# %%
# load points
points = pd.read_csv("./centerline_points_100m.csv")

# %%
# import inverted velocities

fn = './Hubbard.nc'
data = ncf.Dataset(fn)
vx = np.array(data.variables['vx'][:])
vy = data.variables['vy'][:]
t = data.variables['time'][:]

# %%
x = np.array(data.variables['x'][:])
np.shape(vx)
# Out:
# (246, 195, 184)

# %%
x = np.array([[1,2,3],[1,2,3]])
y = np.array([[5,5],[6,6]])
slope = np.array([[.3,.4,.5],[.6,.7,.8]])
idx = np.abs(x-2.1).argmin(axis=1)
idy = np.abs(y-5.1).argmin(axis=0)
print(slope[idy[0], idx[0]])
# Out:
# 0.4

# %%
slope
# Out:
# array([[0.3, 0.4, 0.5],
#        [0.6, 0.7, 0.8]])

# %%
idx
# Out:
# array([0, 0, 0])
